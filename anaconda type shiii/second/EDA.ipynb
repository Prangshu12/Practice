# %% [markdown]
# # Second folder

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("credit_data - credit_data.csv", header=None)
df = pd.read_csv("credit_data - credit_data.csv")
df
# Out:
#       Unnamed: 0 Unnamed: 1 Unnamed: 2    Unnamed: 3             Unnamed: 4  \
# 0            Age     Gender     Income  Credit Score  Credit History Length
# 1             31       Male      36000           604                    487
# 2             25       Male      50000           447                    386
# 3             62      Other     178000           850                    503
# 4             69     Female      46000           668                    349
# ...          ...        ...        ...           ...                    ...
# 65529         53     Female     133000           709                    300
# 65530         69       Male      86000           358                     27
# 65531         23     Female      67000           300                    542
# 65532         64       Male      95000           567                    453
# 65533         48       Male      98000           607                    512
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 65534 entries, 0 to 65533
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   65534 non-null  str
#  1   Unnamed: 1   65534 non-null  str
#  2   Unnamed: 2   65534 non-null  str
#  3   Unnamed: 3   65534 non-null  str
#  4   Unnamed: 4   65534 non-null  str
#  5   Unnamed: 5   65534 non-null  str
#  6   Unnamed: 6   65534 non-null  str
#  7   Unnamed: 7   65534 non-null  str
#  8   Unnamed: 8   65534 non-null  str
#  9   Unnamed: 9   65534 non-null  str
#  10  Unnamed: 10  65534 non-null  str
#  11  Unnamed: 11  65534 non-null  str
#  12  Unnamed: 12  65534 non-null  str
#  13  Unnamed: 13  61243 non-null  str
# dtypes: str(14)
# memory usage: 11.3 MB

# %%
df.head()
# Out:
#   Unnamed: 0 Unnamed: 1 Unnamed: 2    Unnamed: 3             Unnamed: 4  \
# 0        Age     Gender     Income  Credit Score  Credit History Length
# 1         31       Male      36000           604                    487
# 2         25       Male      50000           447                    386
# 3         62      Other     178000           850                    503
# 4         69     Female      46000           668                    349
#
#                  Unnamed: 5   Unnamed: 6   Unnamed: 7         Unnamed: 8  \
# 0  Number of Existing Loans  Loan Amount  Loan Tenure  Existing Customer
# 1                         5       109373          221                 No
# 2                         2       150000           89                 No
# 3                        10        69099          110                Yes
# 4                         6       150000          148                Yes
#
#       Unnamed: 9 Unnamed: 10         Unnamed: 11    Unnamed: 12  \
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0        0
# Unnamed: 1        0
# Unnamed: 2        0
# Unnamed: 3        0
# Unnamed: 4        0
# Unnamed: 5        0
# Unnamed: 6        0
# Unnamed: 7        0
# Unnamed: 8        0
# Unnamed: 9        0
# Unnamed: 10       0
# Unnamed: 11       0
# Unnamed: 12       0
# Unnamed: 13    4291
# dtype: int64

# %%
df.columns
print(df.head())
# Out:
#   Unnamed: 0 Unnamed: 1 Unnamed: 2    Unnamed: 3             Unnamed: 4  \
# 0        Age     Gender     Income  Credit Score  Credit History Length
# 1         31       Male      36000           604                    487
# 2         25       Male      50000           447                    386
# 3         62      Other     178000           850                    503
# 4         69     Female      46000           668                    349
#
#                  Unnamed: 5   Unnamed: 6   Unnamed: 7         Unnamed: 8  \
# 0  Number of Existing Loans  Loan Amount  Loan Tenure  Existing Customer
# 1                         5       109373          221                 No
# 2                         2       150000           89                 No
# 3                        10        69099          110                Yes
# 4                         6       150000          148                Yes
#
#       Unnamed: 9 Unnamed: 10         Unnamed: 11    Unnamed: 12  \
# ...

# %%
df.head()
# Out:
#   Unnamed: 0 Unnamed: 1 Unnamed: 2    Unnamed: 3             Unnamed: 4  \
# 0        Age     Gender     Income  Credit Score  Credit History Length
# 1         31       Male      36000           604                    487
# 2         25       Male      50000           447                    386
# 3         62      Other     178000           850                    503
# 4         69     Female      46000           668                    349
#
#                  Unnamed: 5   Unnamed: 6   Unnamed: 7         Unnamed: 8  \
# 0  Number of Existing Loans  Loan Amount  Loan Tenure  Existing Customer
# 1                         5       109373          221                 No
# 2                         2       150000           89                 No
# 3                        10        69099          110                Yes
# 4                         6       150000          148                Yes
#
#       Unnamed: 9 Unnamed: 10         Unnamed: 11    Unnamed: 12  \
# ...

# %%
df=df.rename(columns={"Unnamed: 0":"Age", "Unnamed: 1":"Gender", "Unnamed: 2":"Income", "Unnamed: 3":"Credit Score","Unnamed: 4":"Credit History Length","unnamed: 5":"Number of existing loans","Unnamed: 6":"Loan Amount","Unnamed: 7":"Loan Tenure","Unnamed: 8":"Existing Customer","Unnamed: 9":"State", "Unnamed: 10":"City", "Unnamed: 11":"Employement Profile","Unnamed: 12":"Profile Score","Unnamed: 13":"Occupation"})
df = df.rename(columns={"Unnamed: 5":"Number of existing loans"})
df
# Out:
#       Age  Gender  Income Credit Score Credit History Length  \
# 1      31    Male   36000          604                   487
# 2      25    Male   50000          447                   386
# 3      62   Other  178000          850                   503
# 4      69  Female   46000          668                   349
# 5      52    Male  132000          601                   553
# ...    ..     ...     ...          ...                   ...
# 65529  53  Female  133000          709                   300
# 65530  69    Male   86000          358                    27
# 65531  23  Female   67000          300                   542
# 65532  64    Male   95000          567                   453
# 65533  48    Male   98000          607                   512
#
#       Number of existing loans Loan Amount Loan Tenure Existing Customer  \
# 1                            5      109373         221                No
# 2                            2      150000          89                No
# ...

# %%
plt.figure(figsize=(8,5))

plt.hist(df["Credit Score"], bins=10)

plt.xlabel("Credit Score")
plt.ylabel("Number of Customers")
plt.title("Credit Score Distribution")

plt.show()

# %%
plt.figure(figsize=(8,5))

plt.hist(df["Age"], bins=10)

plt.xlabel("Age")
plt.ylabel("Number of Customers")
plt.title("Age Distribution")

plt.show()
